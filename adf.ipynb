# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import re

response_Q = requests.get("https://navi.kt.com/faqList.html")
response_Q.encoding = 'utf-8'
html_content = response_Q.text
soup = bs(response_Q.text, 'html.parser')
Q = soup.find_all("a",class_="accordion-trigger")
#print("출력 확인")
#print("Q"[0])

############################

response_A = requests.get("https://navi.kt.com/faqList.html")
response_A.encoding = 'utf-8'
html_content = response_A.text
soup = bs(response_A.text, 'html.parser')
A = soup.find_all("div",class_="accordion-contents")
#print("출력 확인")
#print(A[0])


remain_brakcet = r'\[([^\]]+)\]'

Keyword_list = []

for i in Q:
    K = i.get_text()
    eng_temp = re.findall(remain_brakcet, K)[0]

    Keyword_list.append(eng_temp)
############################

FAQ_list = []
for Question, Answer in zip(Q, A):
    FAQ_list.append(
        {"Question":Question.text.strip(), "Answer":Answer.text.strip()}
        )
    
for i, FAQ in enumerate(FAQ_list, start=1):
    print(f"Q{i} : {FAQ['Question']}")
    print(f"A{i} : {FAQ['Answer']}")


My_dict = {{"Question":Question.text.strip(), "Answer":Answer.text.strip()}}
tuple_list = list(My_dict.items())
print(tuple_list)

#딕 형태니까 key값을 빼와서. 그안에서. []안에 있는 글자만 추출.

print(Keyword_list)
# Out:
# Q1 : [음성인식] 음성인식 통해 할 수 있는 기능은 무엇인가요? (무엇이 좋아지나요?)
# A1 : 원내비를 최신버전으로 업데이트하시면, 다양한 음성인식 기능을 사용하실 수 있습니다.
#
# 												① 목적지 검색 : 상호/주소 검색, 등록된 집/회사 길안내, 최근 목적지, 주변 검색
# 												② 운전 중 경유지 추가 또는 목적지 변경
# 												③ 운전 중 경로 변경 : 무료도로/최소시간 등, 경로 재탐색, 경로 취소
# 												④ 운전 중 경로상 정보 조회 : 전체경로, 전방 교통정보, 카메라 정보, 휴게소 정보, CCTV 보기
# 												⑤ 부가 기능 제어 : 볼륨 조절(크게/작게/음소거), 블랙박스 ON/OFF
# 												⑥ 운전 중 기억해야 할 일이 있을 경우 : ‘O분 뒤에 OOO하라고 알려줘’라고 말하면, O분 후에 해당 메모를 읽어주는 기능
# 												⑦ 운전 중 응급 상황 발생 : 119 연결
# 												⑧ 기타 부가 정보 : 현위치/목적지 날씨 정보, 환율정보, WIKI검색, 재미있는 이야기
#
# 												■ 좌측 상단 메뉴의 환경설정 > 이용팁 을 통해 전체 기능을 보실 수 있습니다.
# Q2 : [음성인식] 음성인식 기능을 어떻게 시작할 수 있나요?
# A2 : 지도 화면 오른쪽 하단에 마이크 버튼을 누르거나 "지니야"라고 불러서 시작할 수 있습니다.
# 											분홍색 음성인식 대기화면이 보이면 명령어를 말씀해주세요.
#
# 											단, '기가지니 호출>음성+버튼 호출' 이 켜져 있는 상황에서는 음성명령 대기 중일 때 전화를 제외한 다른 앱에서 재생되는 미디어/알림의 소리가 차단 또는 제한될 수 있으니, 이 점 유의해주시기 바랍니다.
#
# 											■ 안정적인 음성인식 기능 사용을 위해, 마이크 권한 허용이 필요합니다.
# Q3 : [음성인식] 최신버전으로 앱을 업데이트 했는데 화면에 마이크 버튼이 안 보입니다.
# A3 : 안정적인 서비스 제공을 위해 테스트가 완료되는 단말부터 순차적으로 음성인식 서비스가 제공되고 있습니다.
# 												현재 음성인식 사용 가능한 단말은 앱내 공지사항을 통해 확인하실 수 있습니다.
# Q4 : [음성인식] 제 단말은 음성인식 지원 단말인데 '마이크 버튼'이 안 보입니다. 어떻게 하면 되나요?
# A4 : 음성인식 기능 사용을 위해서는 먼저 마이크 권한 허용이 필요합니다.
# 												- 화면 좌측 상단 메뉴의 환경설정 > 내비정보 > 앱 접근 권한 > 선택권한 항목 중 '마이크' 권한을 허용해주세요.
# 												- 마이크 권한 동의 후, 재동의 버튼을 누르시면 앱이 자동으로 재실행되며, OS 권한 팝업에 동의해주시면 음성인식 기능 사용이 가능합니다.
#
# 												마이크 권한 동의 후에도 마이크 버튼 이 안 보이시는 경우라면
# 												- 좌측 상단 메뉴의  환경설정 > 음성인식 > 기가지니 사용/음성+버튼 & “지니야”로 호출을 확인 후 체크해주세요.
# Q5 : [음성인식] 음성인식 사용 중에도 데이터 요금은 무료인가요?
# A5 : KT 고객은 음성인식 사용 시 데이터 통화료와 정보이용료가 무료입니다.
# 												향후 음성인식을 통해 제공되는 기능에 따라 별도 안내드릴 예정입니다.
# Q6 : [음성인식] 음성인식이 잘 안됩니다. 어떻게 하면 되나요?
# A6 : 운전 중 주변의 소음에 따라 인식률에 차이가 있을 수 있습니다.
# 												마이크 주변 소음을 가능한 줄여주시고, 차량 블루투스로 연결하여 사용하시면 더 잘 인식됩니다.
# Q7 : [음성인식] IOS는 언제부터 사용 가능한가요?
# A7 : 18년 1Q내에 제공해드리기 위해 열심히 노력 중입니다.
# Q8 : [요금문의] 데이터 요금은 무료인가요?
# A8 : KT 고객은 내비 이용시 발생하는 데이터 통화료와 정보이용료가 무료입니다.
# 												단, 마켓을 통해서 앱 다운로드와 업데이트를 받으실 경우에는 데이터 요금이 발생하오니, Wi-Fi에서 다운받으시기를 권장합니다.
# 												타 통신사 고객의 경우에는 데이터 요금이 발생하며, 가입된 요금제에 따라 다를 수 있습니다.
# 												*어플 및 지도 데이터 업데이트 시 최대 300 MB 정도의 데이터가 소모될 수 있으며, 지도 미리받기를 한 경우 1km 당 약 0.04MB 정도의 데이터가 사용되나, 스트리밍 지도를 사용하거나, 실제 주행 환경에  따라 차이가 있을 수 있습니다. (데이터 용량 및 차감 안내 표시됨)
# Q9 : [앱 다운로드/업데이트] '설치할 수 없습니다.' 오류메세지가 보이거나 앱 실행시 바로 종료됩니다.
# A9 : 해당 현상이 반복되는 경우, 불편하시더라도 앱 삭제 및  재설치 후 이용해주시기 바랍니다. 이후에도 동일한 오류가 발생할 경우, 앱내 제보하기 또는 1800-8855로 문의 주시기 바랍니다.
# Q10 : [데이터 삭제] 최근 검색어를 삭제하고 싶습니다.
# A10 : 최근 검색어 리스트 상단 우측에 편집 버튼을 선택하신 후 편집 화면에서 삭제를 원하시는 리스트를 선택하시고 삭제 버튼을 누르시면 삭제가 됩니다.
# Q11 : [데이터 삭제] 이전 목적지를 삭제하고 싶습니다.
# A11 : 초기 화면 상단에 검색 바를 선택하신 후 검색 바 밑에 이전목적지 버튼을 선택하시면 이전목적지 화면으로 이동이 됩니다.
# 												이전목적지 화면 상단 우측에 편집 버튼을 선택하신 후 편집 화면에서 삭제를 원하시는 리스트를 선택하시고 삭제 버튼을 누르시면 삭제가 됩니다
# Q12 : [검색 오류] 목적지 검색이 안됩니다.
# A12 : 입력창에 명칭, 주소, 전화번호를 입력하시고, 검색 버튼을 누르시면 목적지 검색이 진행됩니다.
#
# 												'검색된 결과가 없습니다.'라는 결과가 표시되면 검색 데이터가 누락된 경우일 수 있으니, 하단 ‘문의하기’ 버튼 선택 후 '장소정보 등록/변경' 메뉴를 통해서 등록해주시면 빠른시간 내에 반영하도록 하겠습니다.
# Q13 : [GPS 수신 및 현위치 탐색] 현재 위치(출발지)가 아닌 다른 곳을 잡거나 지도가 멈춰 있습니다.
# A13 : 위치(GPS) 기능을 ON/OFF 해보시고, GPS 신호가 정상 수신될 때까지 프로그램을 종료하지 않고 기다려주시거나 단말 전원을 껐다 켜신 후 사용해 주시기 바랍니다.
# 												원활한 GPS 수신을 위해 차량 거치대를 사용하여 하늘이 개방되어 있는 곳에 거치하여 사용하시는 것을 권장합니다.
# 												이후에도 동일현상 발생 시, GPS 모듈의 수신기능은 단말의 기능이므로 제조사 AS 센터에 방문하셔서 GPS 기능 점검을 받아보시기 바랍니다.
# Q14 : [음량조절] 블루투스를 연결하여 사용하는데 내비게이션 때문에 음악소리가 작아졌습니다.
# A14 : 차량 장착 블루투스를 연결하여 음악 어플(지니 등)과 통합내비를 동시에 연결해서 사용하실 경우, 음악 소리를 동일한 크기로 들으려면 '사이드메뉴-환경설정-음성안내설정-음성안내 음량 자동 조절' 기능을 OFF로 설정하시면 됩니다.
# 												또한 통화전용 블루투스의 경우, 내비게이션 음성 안내가 되지 않으며 차종에 따라 블루투스 음량설정이 우선하게 되는 경우에도 볼륨 자동 조절기능이 제공되지 않을 수도 있으니 참고해주시기 바랍니다.
# Q15 : [음량조절] 음량 조절이 되지 않습니다.
# A15 : 미디어 볼륨과 연동되고 있으므로 단말기의 최대 미디어 볼륨 크기와 동일하게 음량이 제공될 수 있습니다.
# 												음량 설정은 지도 화면을 한번 터치하시면 왼쪽 하단의 볼륨 버튼이 표시되고 조절이 가능하오니
# 												설정값이 낮게 설정되어 있는지 확인 후 볼륨을 높여서 이용 부탁드립니다.
# 												* 블루투스 기기와 연결하게 되면 블루투스의 음량설정이 우선하게 되는 경우가 있어 볼륨조절 기능이 동작하지 않을 수도 있으니 참고해주시기 바랍니다.
# Q16 : [음량조절] 안내음성이 전혀 들리지 않습니다.
# A16 : 음성안내가 제공되지 않으신다면 단말기에 음소거 되어 있지 않았는지 또는 어플 음량 설정값이 0 으로 되어 있는지 확인이 필요합니다.
# 												단말기 전원을 껐다 켜신 후 사용해보시고, 불필요한 프로그램의 멀티태스킹 종료 및 삭제 후 이용 부탁드립니다.  해당 현상이 자주 발생하시면 프로그램 삭제/재설치 후 이용을 부탁드립니다.
# 												지도가 멈추면 주행으로 판단하지 않으므로 음성안내가 진행되지 않습니다.
# 												지도 이동 여부도 함께 확인 부탁드립니다.
# Q17 : [길 안내 오류] 목적지 도착 후 주차장이 아닌 자동차가 진입할 수 없는 곳으로 안내됩니다.
# A17 : '명칭검색'과 '주소검색'을 제공하고 있습니다.
# 												'명칭검색'은 상호/건물 이름으로 검색하는 것이고, '주소검색'은 번지, 건물번호(새주소)로 검색합니다.
# 												'명칭검색'은 자동차에 적합하게 건물의 주차장 근처나 건물의 입구 앞으로 안내하여 종료하지만
# 												‘주소검색’은 검색하신 번지의 중심점으로 안내되는 차이가 있으니 서비스 이용 시 참고해주시기 바랍니다.
# Q18 : [길 안내 오류] 목적지에 도착하지 않았는데 도착했다고 나옵니다.
# A18 : 목적지 근방에서 종료하는 현상은 해당 목적지의 위치 좌표가 종료 지점이었는지 혹은 위치 좌표는 맞으나 GPS 수신 오차가 발생하여 근방에서 종료하였는지를 확인하는 것이 중요합니다.
# 												목적지 20~30m 을 기준으로 하여 GPS 수신율에 따라 도착지 완료 안내가 결정되기 때문입니다.
# 												GPS 수신율이 좋지 않은 경우, 목적지 근방 종료의 오차가 커질 수 있음을 양해 부탁 드립니다.
# Q19 : [기타] 타사 단말에 kt 유심 카드를 사용하고 있습니다. 이용이 가능한가요?
# A19 : 유심카드만 꼽혀있다면, 통신사와 상관없이 이용 가능합니다.
# Q20 : [기타] 내비 이용 시 유난히 빠르게 배터리가 소모됩니다.
# A20 : 폰 배터리를 체크하는 기능은 폰 자체의 기능입니다.
# 												다만 내비게이션 기능을 이용하면 폰 내부에 포함되어 있는 GPS칩이 항상 동작을 하기 때문에 일반 대기상태나 부가서비스보다는 배터리 소모량이 많습니다.
# 												내비 이용 시에는 차량의 충전기를 이용하는 것을 권장해드리니 참고해주시기 바랍니다.
# Q21 : [기타] 네트워크 접속 문제에 대한 팝업이 뜨고 서비스 실행이 안됩니다.
# A21 : 3G/LTE 접속 시 인증 및 안정적인 길안내가 가능하므로 Wi-Fi가 활성화되어 있지 않은지 확인해주시기 바랍니다.
# 												단말 Wi-Fi를 비활성화한 후에도 동일현상이 반복적으로 발생할 경우,  kt고객센터(114)로 연락주셔서 네트워크 점검을 받아주시기 바랍니다.
# Q22 : [기타] 웨어러블 디바이스 지원이 가능한가요?
# A22 : 현재 Apple Watch (OS 2 이상) 만 지원하고 있습니다.
# 												기존 KT내비를 사용하시는 고객님께서는 Apple Watch OS 버전을 확인하신 후 OS 2 이상으로 업데이트 하셔야 사용 가능합니다.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 47
#      43     print(f"Q{i} : {FAQ['Question']}")
#      44     print(f"A{i} : {FAQ['Answer']}")
# ---> 47 My_dict = {{"Question":Question.text.strip(), "Answer":Answer.text.strip()}}
#      48 tuple_list = list(My_dict.items())
#      49 print(tuple_list)
#
# TypeError: unhashable type: 'dict'
